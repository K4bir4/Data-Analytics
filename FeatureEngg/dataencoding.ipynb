# %%
##data encoding
#1 Nominal/OHE encoding
#2 Label and Ordinal Encoding 
#3 Target Guided ordinal encoding

# %%
#1nominal 
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
df= pd.DataFrame({
    'color':['red','blue','green','greem','red','blue']
})

# %%
df.head()
# Out:
#    color
# 0    red
# 1   blue
# 2  green
# 3  greem
# 4    red
